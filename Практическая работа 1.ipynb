# %%
import math
a = 5
b = 2
print ( a+b )
print ( a-b )
print ( a*b )
print ( a/b )
print ( a>b )
print ( a<b )
print ( a==b )
print ( a!=b )
print ( "Привет! Меня зовут Екатерина")
x = input("введите число:")
print ( "Вы ввели число", x )
# Out:
# 7
# 3
# 10
# 2.5
# True
# False
# False
# True
# Привет! Меня зовут Екатерина
# введите число:23
# Вы ввели число 23
